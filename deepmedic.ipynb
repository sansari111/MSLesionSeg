# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls
# Out:
# drive  sample_data

# %%
# %cd /content/drive/MyDrive/deepmedic-master
# Out:
# /content/drive/MyDrive/deepmedic-master

# %%
# !pip install .
# Out:
# Processing /content/drive/My Drive/deepmedic-master
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# ...
#   Created wheel for deepmedic: filename=deepmedic-0.8.4-py3-none-any.whl size=127332 sha256=cbcec59a0f795cf96746361165f015d7dacf6c37c51a20b5875bc277a6886dcc
#   Stored in directory: /root/.cache/pip/wheels/65/18/1b/e4af3b14739e03a50936ed767fd8f980d05d06dadafd083843
# Successfully built deepmedic
# ...

# %%
# !chmod 755 deepMedicRun

# %%
# !./deepMedicRun -h
# Out:
# usage: DeepMedic [-h] [-model MODEL_CFG] [-train TRAIN_CFG] [-test TEST_CFG]
#                  [-load SAVED_MODEL] [-dev DEVICE] [-resetopt]
#
# This software allows creation and supervised training of 3D, multi-scale CNN models for segmentation of structures in biomedical NIFTI volumes.
# The project is hosted at: https://github.com/Kamnitsask/deepmedic
# See the documentation for details on its use.
# This software accompanies the research presented in:
# Kamnitsas et al, "Efficient Multi-Scale 3D CNN with Fully Connected CRF for Accurate Brain Lesion Segmentation", Biomedical Image Analysis, 2016.
# We hope our work aids you in your endeavours.
# For questions and feedback contact: konstantinos.kamnitsas12@ic.ac.uk
#
# optional arguments:
#   -h, --help         show this help message and exit
#   -model MODEL_CFG   Specify the architecture of the model to be used, by providing a config file [MODEL_CFG].
# ...

# %%
# !rm -rf /content/drive/MyDrive/deepmedic-master/examples/output

# %%
# !./deepMedicRun -model ./examples/configFiles/deepMedic/model/modelConfig.cfg \
               -train ./examples/configFiles/deepMedic/train/trainConfig.cfg \
               -dev cuda0

# %%
# !./deepMedicRun -model ./examples/configFiles/deepMedic/model/modelConfig.cfg \
               -train ./examples/configFiles/deepMedic/train/trainConfig.cfg \
               -load ./examples/output/saved_models/trainSessionDm/deepMedic.trainSessionDm.2021-08-20.15.32.01.693130.model.ckpt\
               -dev cuda0
# Out:
# Streaming output truncated to the last 5000 lines.
# [TRA|JOB:25|PID:342] Started. (#25/34) sampling job. Load & sample from subject of index (in user's list): 0
# [TRA|JOB:25|PID:342] Loading subject with 1st channel at: /content/drive/MyDrive/deepmedic-master/examples/dataForExamples/isbi2015TrainingData/train/isbi_2015_pat0001_1/flair_subtrMeanDivStd.nii
# [TRA|JOB:25|PID:342] Done. Samples per category: [Foreground: 30/30] [Background: 29/29]
# [TRA|JOB:25|PID:342] TIMING: [Load: 5.6] [Preproc: 1.0] [Augm-Img: 0.0] [Sample Coords: 0.1] [Extract Sampl: 0.0] [Augm-Samples: 0.0] secs
# [TRA|JOB:26|PID:342] Started. (#26/34) sampling job. Load & sample from subject of index (in user's list): 9
# [TRA|JOB:26|PID:342] Loading subject with 1st channel at: /content/drive/MyDrive/deepmedic-master/examples/dataForExamples/isbi2015TrainingData/train/isbi_2015_pat0002_1_rator2/flair_subtrMeanDivStd.nii
# ...

# %% [markdown]
# **Testing**

# %%
# !./deepMedicRun -model ./examples/configFiles/deepMedic/model/modelConfig.cfg \
               -test ./examples/configFiles/deepMedic/test/testConfig.cfg \
               -load /content/drive/MyDrive/deepmedic-master/examples/output/saved_models/trainSessionDm/deepMedic.trainSessionDm.final.2021-08-22.07.30.16.783815.model.ckpt\
               -dev cuda0
# Out:
# Given configuration file:  /content/drive/My Drive/deepmedic-master/examples/configFiles/deepMedic/model/modelConfig.cfg
# Given configuration file:  /content/drive/My Drive/deepmedic-master/examples/configFiles/deepMedic/test/testConfig.cfg
# Creating necessary folders for testing session...
# 	>>Created folder for session:  /content/drive/My Drive/deepmedic-master/examples/output/predictions/testSessionDm
# 	>>Created folder for segmentations and probability maps:  /content/drive/My Drive/deepmedic-master/examples/output/predictions/testSessionDm/predictions/
# 	>>Created folder for features:  /content/drive/My Drive/deepmedic-master/examples/output/predictions/testSessionDm/features/
# =============================== logger created =======================================
#
# ======================== Starting new session ============================
# Command line arguments given:
# ...
